# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('sneep-2021.csv')
df.sample(3)
# Out:
#        censo_anio  provincia_sneep_id provincia_descripcion  \
# 27812        2021                   3               Córdoba
# 81778        2021                   1          Buenos Aires
# 99948        2021                   1          Buenos Aires
#
#        establecimiento_id            establecimiento_descripcion  edad  \
# 27812                  30  COMPLEJO CARCELARIO Nº 1 MODULO M.X.2    40
# 81778                 270           UNIDAD 42 - FLORENCIO VARELA    20
# 99948                 116           UNIDAD 23 - FLORENCIO VARELA    48
#
#        genero_id genero_descripcion  nacionalidad_id nacionalidad_descripcion  \
# 27812          1              Varón                1                Argentina
# 81778          1              Varón                1                Argentina
# 99948          1              Varón                1                Argentina
#
#        ...  participa_programa_pre_libertad  \
# 27812  ...                              NaN
# 81778  ...                              0.0
# 99948  ...                              NaN
#
#       participa_programa_prision_discontinua_id  \
# 27812                                         0
# 81778                                         1
# 99948                                         0
#
#        participa_programa_prision_discontinua_descripcion  \
# 27812                                                NaN
# 81778                              No está incorporado/a
# 99948                                                NaN
#
#       participa_programa_semi_detencion_id  \
# 27812                                    0
# 81778                                    1
# 99948                                    0
#
#        participa_programa_semi_detencion_descripcion tuvo_reduccion_pena_id  \
# 27812                                            NaN                      0
# 81778                         No tiene semidetención                      4
# 99948                                            NaN                      0
#
#        tuvo_reduccion_pena_descripcion mujer_tiene_hijos_intramuro  \
# 27812                              NaN                         NaN
# 81778        No tuvo reducción de pena                         NaN
# 99948                              NaN                         NaN
#
#        provincia_id ultima_provincia_residencia_id
# 27812            14                           14.0
# 81778             6                            6.0
# 99948             6                            6.0
#
# [3 rows x 86 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101267 entries, 0 to 101266
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   censo_anio                                          101267 non-null  int64
#  1   provincia_sneep_id                                  101267 non-null  int64
#  2   provincia_descripcion                               101267 non-null  object
#  3   establecimiento_id                                  101267 non-null  int64
#  4   establecimiento_descripcion                         101267 non-null  object
#  5   edad                                                101267 non-null  int64
#  6   genero_id                                           101267 non-null  int64
#  7   genero_descripcion                                  101267 non-null  object
#  8   nacionalidad_id                                     101267 non-null  int64
#  9   nacionalidad_descripcion                            101234 non-null  object
#  10  estado_civil_id                                     101267 non-null  int64
#  11  estado_civil_descripcion                            98968 non-null   object
#  12  nivel_instruccion_id                                101267 non-null  int64
#  13  nivel_instruccion_descripcion                       99729 non-null   object
#  14  ultima_situacion_laboral_id                         101267 non-null  int64
#  15  ultima_situacion_laboral_descripcion                99404 non-null   object
#  16  capacitacion_laboral_al_ingresar_id                 101267 non-null  int64
#  17  capacitacion_laboral_al_ingresar_descripcion        100681 non-null  object
#  18  ultimo_lugar_residencia_id                          101267 non-null  int64
#  19  ultimo_lugar_residencia_descripcion                 101129 non-null  object
#  20  ultima_provincia_residencia_sneep_id                101267 non-null  int64
#  21  ultima_provincia_residencia_descripcion             100853 non-null  object
#  22  jurisdiccion_id                                     101267 non-null  int64
#  23  jurisdiccion_descripcion                            101255 non-null  object
#  24  situacion_legal_id                                  101267 non-null  int64
#  25  situacion_legal_descripcion                         101267 non-null  object
#  26  fecha_detencion                                     96678 non-null   object
#  27  fecha_condenado                                     52078 non-null   object
#  28  establecimiento_procedencia_id                      101267 non-null  int64
#  29  establecimiento_procedencia_descripcion             101129 non-null  object
#  30  delito1_id                                          101267 non-null  int64
#  31  delito1_descripcion                                 99346 non-null   object
#  32  delito2_id                                          101267 non-null  int64
#  33  delito2_descripcion                                 20488 non-null   object
#  34  delito3_id                                          101267 non-null  int64
#  35  delito3_descripcion                                 5071 non-null    object
#  36  delito4_id                                          101267 non-null  int64
#  37  delito4_descripcion                                 1947 non-null    object
#  38  delito5_id                                          101267 non-null  int64
#  39  delito5_descripcion                                 893 non-null     object
#  40  horas_trabajo_remunerado_id                         101267 non-null  int64
#  41  horas_trabajo_remunerado_descripcion                96635 non-null   object
#  42  participacion_programa_laboral                      98286 non-null   float64
#  43  participacion_programa_educativo_id                 101267 non-null  int64
#  44  participacion_programa_educativo_descripcion        98239 non-null   object
#  45  participacion_actividades_deportivas                99672 non-null   float64
#  46  recibio_atencion_medica_ult_anio                    101267 non-null  int64
#  47  recibio_atencion_medica_ult_anio_descripcion        96445 non-null   object
#  48  recibio_visitas_ultimo_anio                         101169 non-null  float64
#  49  participo_alteracion_orden_ult_anio_id              101267 non-null  int64
#  50  participo_alteracion_orden_ult_anio_descripcion     101126 non-null  object
#  51  tipo_infraccion_disciplinaria_id                    101267 non-null  int64
#  52  tipo_infraccion_disciplinaria_descripcion           100679 non-null  object
#  53  sancion_aplicada_id                                 101267 non-null  int64
#  54  sancion_aplicada_descripcion                        14834 non-null   object
#  55  calificacion_conducta_id                            101267 non-null  int64
#  56  calificacion_conducta_descripcion                   99469 non-null   object
#  57  tentativa_fugas_evasiones_id                        101267 non-null  int64
#  58  tentativa_fugas_evasiones_descripcion               100928 non-null  object
#  59  tentativa_suicidio                                  101267 non-null  int64
#  60  fue_lesionado_id                                    101267 non-null  int64
#  61  fue_lesionado_descripcion                           98354 non-null   object
#  62  duracion_condena_anios                              101267 non-null  int64
#  63  duracion_condena_meses                              101267 non-null  int64
#  64  duracion_condena_rango                              101267 non-null  int64
#  65  tipo_condena                                        54693 non-null   float64
#  66  es_reincidente_id                                   101267 non-null  int64
#  67  es_reincidente_descripcion                          53716 non-null   object
#  68  tiene_periodo_progresividad_id                      101267 non-null  int64
#  69  tiene_periodo_progresividad_descripcion             54541 non-null   object
#  70  reparticion_id                                      101267 non-null  int64
#  71  reparticion_descripcion                             101267 non-null  object
#  72  tuvo_salidas_transitorias_id                        101267 non-null  int64
#  73  tuvo_salidas_transitorias_descripcion               54985 non-null   object
#  74  incorporado_reg_semi_libertad_id                    101267 non-null  int64
#  75  incorporado_reg_semi_libertad_descripcion           55466 non-null   object
#  76  participa_programa_pre_libertad                     54634 non-null   float64
#  77  participa_programa_prision_discontinua_id           101267 non-null  int64
#  78  participa_programa_prision_discontinua_descripcion  55248 non-null   object
#  79  participa_programa_semi_detencion_id                101267 non-null  int64
#  80  participa_programa_semi_detencion_descripcion       55620 non-null   object
#  81  tuvo_reduccion_pena_id                              101267 non-null  int64
#  82  tuvo_reduccion_pena_descripcion                     53941 non-null   object
#  83  mujer_tiene_hijos_intramuro                         4476 non-null    float64
#  84  provincia_id                                        101267 non-null  int64
#  85  ultima_provincia_residencia_id                      100853 non-null  float64
# dtypes: float64(7), int64(42), object(37)
# memory usage: 66.4+ MB

# %%
categorical_columns=[col for col in df.columns if df[col].dtypes == 'object']
numerical_columns=[col for col in df.columns if df[col].dtypes != 'object']

# %%
numerical_columns
# Out:
# ['censo_anio',
#  'provincia_sneep_id',
#  'establecimiento_id',
#  'edad',
#  'genero_id',
#  'nacionalidad_id',
#  'estado_civil_id',
#  'nivel_instruccion_id',
#  'ultima_situacion_laboral_id',
#  'capacitacion_laboral_al_ingresar_id',
#  'ultimo_lugar_residencia_id',
#  'ultima_provincia_residencia_sneep_id',
#  'jurisdiccion_id',
#  'situacion_legal_id',
#  'establecimiento_procedencia_id',
#  'delito1_id',
#  'delito2_id',
#  'delito3_id',
#  'delito4_id',
#  'delito5_id',
#  'horas_trabajo_remunerado_id',
#  'participacion_programa_laboral',
#  'participacion_programa_educativo_id',
#  'participacion_actividades_deportivas',
#  'recibio_atencion_medica_ult_anio',
#  'recibio_visitas_ultimo_anio',
#  'participo_alteracion_orden_ult_anio_id',
#  'tipo_infraccion_disciplinaria_id',
#  'sancion_aplicada_id',
#  'calificacion_conducta_id',
#  'tentativa_fugas_evasiones_id',
#  'tentativa_suicidio',
#  'fue_lesionado_id',
#  'duracion_condena_anios',
#  'duracion_condena_meses',
#  'duracion_condena_rango',
#  'tipo_condena',
#  'es_reincidente_id',
#  'tiene_periodo_progresividad_id',
#  'reparticion_id',
#  'tuvo_salidas_transitorias_id',
#  'incorporado_reg_semi_libertad_id',
#  'participa_programa_pre_libertad',
#  'participa_programa_prision_discontinua_id',
#  'participa_programa_semi_detencion_id',
#  'tuvo_reduccion_pena_id',
#  'mujer_tiene_hijos_intramuro',
#  'provincia_id',
#  'ultima_provincia_residencia_id']
